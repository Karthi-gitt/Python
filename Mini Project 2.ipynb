# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('/content/netflix_titles.csv')
print(df.shape)
print(df.info())
print(df.head())
# Out:
# (8807, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
# None
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

content_type_counts = df['type'].value_counts()
content_type_counts.plot(kind='bar')
plt.xlabel('Content Type')
plt.ylabel('Count')
plt.title('Distribution of Content Types')
plt.show()

# %%
#country contribution using bar
content_type_counts = df['country'].value_counts().head(10)
content_type_counts.plot(kind='bar')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.title('countries contribution')
plt.show()

# %%
#country contribution using lineplot
content_counts = df['country'].value_counts().head(10)
plt.figure(figsize=(10,5))
plt.plot(content_counts.index, content_counts.values)
content_counts.plot(kind='line')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.title('countries contribution')
plt.show()

# %%
#Which directors have the most titles on Netflix
director_counts = df['director'].value_counts().head(10)
director_counts.plot(kind='bar')
plt.xlabel('Directors')
plt.ylabel('Count')
plt.title('Directors contribution')
plt.show()

#country contribution using bar
content_type_counts = df['country'].value_counts().head(10)
content_type_counts.plot(kind='bar')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.title('countries contribution')
plt.show()

# %%
# Get the count of each content type
content_type_counts = df['type'].value_counts()

# Display the counts
display(content_type_counts)

#countries contribution
print(df['country'].value_counts().head(10))

#Which directors have the most titles on Netflix
print(df['director'].value_counts().head(10))
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Suhas Kadav               16
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64
